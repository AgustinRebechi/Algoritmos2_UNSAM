# %% [markdown]
# ## Ejercicio 1
# Implemente la clase Lamparita, que sirva para representar el estado de encendido
# de una lamparita (encendido o apagado). Defina, asimismo, dos métodos que
# permitan encender y apagar la luz de la lamparita y otro que indique en qué
# estado se encuentra. La lamparita inicialmente está apagada

# %%
class Lampara:

    def __init__(self):
        self.estado = False

    def encender(self):
        self.estado = True

    def apagar(self):
        self.estado = False

    def mostrar(self):
        print(f'El estado es {self.estado}')

calida = Lampara() # Inicializo instancia calida de clase Lampara

calida.mostrar()
calida.encender()
calida.mostrar()
# Out:
# El estado es False
# El estado es True
